# %%
import welly

data_location = 'WA1.las'

project = welly.read_las(data_location)

well = project[0]

tracks = ['SP',
          'GR',
          'CALI',
          ['LL8', 'ILM', 'ILD'],
          ['RHOB', 'NPHI'],
          'DT']

well.plot(tracks=tracks)
# Out:
# 1it [00:00, 10.16it/s]
# /home/simon/Documents/hal_interview/geo_interview/venv/lib/python3.12/site-packages/welly/curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
